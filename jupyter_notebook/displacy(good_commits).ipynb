# %%
import spacy
from spacy import displacy

# %%
nlp = spacy.load("en_core_web_lg")

# %%
spacy.explain('PROPN')
# Out:
# 'proper noun'

# %%
doc6 = nlp("start parse gas mix suunto xml crazy helium percentage companion would hepct0 number first could see sane only mix value should exist start indexing multiple mix expect hepct1 right wrong xml people crazy second mix percentage o2pct2 percentage onebase implicit percentage zerobase explicit second mix o2pct2 hepct1 like ask drug suunto people finnish company need ask vodka explain lot lot vodka comparison output nice sane use many different xml nesting node check make array different noce allow mark suunto case check crazy alcoholic xml entry suunto file type file thing good idea decide default unit day ")
for token in doc6:
    print([token.text, token.tag_, token.pos_])
# Out:
# ['start', 'VB', 'VERB']
# ['parse', 'VB', 'VERB']
# ['gas', 'NN', 'NOUN']
# ['mix', 'NN', 'NOUN']
# ['suunto', 'NN', 'NOUN']
# ['xml', 'NN', 'NOUN']
# ['crazy', 'NNP', 'PROPN']
# ['helium', 'NN', 'NOUN']
# ['percentage', 'NN', 'NOUN']
# ['companion', 'NN', 'NOUN']
# ['would', 'MD', 'VERB']
# ['hepct0', 'NN', 'NOUN']
# ['number', 'NN', 'NOUN']
# ['first', 'RB', 'ADV']
# ['could', 'MD', 'VERB']
# ['see', 'VB', 'VERB']
# ['sane', 'JJ', 'ADJ']
# ['only', 'JJ', 'ADJ']
# ['mix', 'NN', 'NOUN']
# ['value', 'NN', 'NOUN']
# ['should', 'MD', 'VERB']
# ['exist', 'VB', 'VERB']
# ['start', 'VB', 'VERB']
# ['indexing', 'VBG', 'VERB']
# ['multiple', 'JJ', 'ADJ']
# ['mix', 'NN', 'NOUN']
# ['expect', 'VB', 'VERB']
# ['hepct1', 'NN', 'NOUN']
# ['right', 'JJ', 'ADJ']
# ['wrong', 'JJ', 'ADJ']
# ['xml', 'NN', 'NOUN']
# ['people', 'NNS', 'NOUN']
# ['crazy', 'JJ', 'ADJ']
# ['second', 'JJ', 'ADJ']
# ['mix', 'NN', 'NOUN']
# ['percentage', 'NN', 'NOUN']
# ['o2pct2', 'NNP', 'PROPN']
# ...

# %%
doc6 = nlp("start parsing gas mixes the suunto xml is just completely crazy  whats the helium percentage companion to o2pct would it be hepct no its hepct0 ok so they didnt number the first o2pct which could be seen as sane thats the only mix value that should always exist  and they clearly started their indexing with 0  so with multiple mixes youd then expect o2pct1 and hepct1 right wrong because xml people are crazy the second o2 mix percentage is obviously o2pct2  so the o2 percentages are onebased with an implicit one  but the he percentages are zerobased with an explicit zero  so the second mix is o2pct2 and hepct1 id like to ask what drugs suunto people are on but hey its a finnish company  no need to ask  vodka explains everything  lots and lots of vodka in comparison the libdivecomputer output is nice and sane and uses a gasmix node  of course now we have so many different xml nesting nodes to check that i just made it an array of different noces  that also allows me to mark the suunto case so that we only do the check for crazy alcoholic xml entries when its a suunto file the type of file thing is probably a good idea for deciding on default units too some day signedoffby linus torvalds torvalds@linuxfoundationorg") 
for token in doc6:
    print([token.text, token.tag_, token.pos_])
# Out:
# ['start', 'VB', 'VERB']
# ['parsing', 'VBG', 'VERB']
# ['gas', 'NN', 'NOUN']
# ['mixes', 'VBZ', 'VERB']
# ['the', 'DT', 'DET']
# ['suunto', 'NN', 'NOUN']
# ['xml', 'NN', 'NOUN']
# ['is', 'VBZ', 'AUX']
# ['just', 'RB', 'ADV']
# ['completely', 'RB', 'ADV']
# ['crazy', 'JJ', 'ADJ']
# [' ', '_SP', 'SPACE']
# ['what', 'WP', 'PRON']
# ['s', 'VBZ', 'VERB']
# ['the', 'DT', 'DET']
# ['helium', 'NN', 'NOUN']
# ['percentage', 'NN', 'NOUN']
# ['companion', 'NN', 'NOUN']
# ['to', 'IN', 'ADP']
# ['o2pct', 'NNP', 'PROPN']
# ['would', 'MD', 'VERB']
# ['it', 'PRP', 'PRON']
# ['be', 'VB', 'AUX']
# ['hepct', 'NNP', 'PROPN']
# ['no', 'DT', 'DET']
# ['its', 'PRP$', 'DET']
# ['hepct0', 'NN', 'NOUN']
# ['ok', 'UH', 'INTJ']
# ['so', 'RB', 'ADV']
# ['they', 'PRP', 'PRON']
# ['did', 'VBD', 'AUX']
# ['nt', 'RB', 'PART']
# ['number', 'NN', 'NOUN']
# ['the', 'DT', 'DET']
# ['first', 'JJ', 'ADJ']
# ['o2pct', 'NNP', 'PROPN']
# ['which', 'WDT', 'DET']
# ['could', 'MD', 'VERB']
# ['be', 'VB', 'AUX']
# ...

# %%
nlp.tokenizer.add_special_case('fix', [{ORTH: 'fixing'}])  # treat fix as verb
subject_line = "Switch from pgp.mit.edu to pool.sks-keyservers.net"
subject_line = subject_line.replace(' .', ' ')
subject_line = subject_line.replace('\'', '')
doc1 = nlp(subject_line)
print([(token.text, token.tag_, token.pos_) for token in doc1])
displacy.render(doc1)
# Out:
# [('Remove', 'VB', 'VERB'), ('the', 'DT', 'DET'), ('half', 'JJ', 'ADJ'), ('-', 'HYPH', 'PUNCT'), ('duplex', 'NN', 'NOUN'), ('emulation', 'NN', 'NOUN'), ('from', 'IN', 'ADP'), ('the', 'DT', 'DET'), ('I', 'NNP', 'PROPN'), ('/', 'SYM', 'SYM'), ('O', 'NN', 'NOUN'), ('api', 'NN', 'NOUN')]
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="240a7fce72d7438babed10beeaf43322-0" class="displacy" width="1800" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Remove</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
# ...

# %%
doc2 = nlp("Use the new timer for the timeout calculations")
print([(token.text, token.tag_, token.pos_) for token in doc2])
displacy.render(doc2)
# Out:
# [('Use', 'VB', 'VERB'), ('the', 'DT', 'DET'), ('new', 'JJ', 'ADJ'), ('timer', 'NN', 'NOUN'), ('for', 'IN', 'ADP'), ('the', 'DT', 'DET'), ('timeout', 'NN', 'NOUN'), ('calculations', 'NNS', 'NOUN')]
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="0d74f3153d914d0e85ed0f0cea166a6f-0" class="displacy" width="1450" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Use</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">the</tspan>
# ...

# %%
doc3 = nlp("Add a high resolution timer module")
print([(token.text, token.tag_, token.pos_) for token in doc3])
displacy.render(doc3)
# Out:
# [('Add', 'VB', 'VERB'), ('a', 'DT', 'DET'), ('high', 'JJ', 'ADJ'), ('resolution', 'NN', 'NOUN'), ('timer', 'NN', 'NOUN'), ('module', 'NN', 'NOUN')]
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="6ced30f8a75043a7a6b9b36a870b0c24-0" class="displacy" width="1100" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Add</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">DET</tspan>
# </text>
#
# ...

# %%
doc4 = nlp("Add functions for converting bluetooth addresses")
for token in doc4:
    print([token.text, token.dep_])
    for child in token.children:
           print('children: ', child)
displacy.render(doc4)
# Out:
# ['Add', 'ROOT']
# children:  functions
# ['functions', 'dobj']
# children:  for
# ['for', 'prep']
# children:  converting
# ['converting', 'pcomp']
# children:  addresses
# ['bluetooth', 'compound']
# ['addresses', 'dobj']
# children:  bluetooth
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="4bdd84e72d6d4aa1ad9bc657dbcefb72-0" class="displacy" width="1100" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Add</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
# ...

# %%
doc5 = nlp("Add support for the OSTC 2 TR")
print([(token.text, token.tag_, token.pos_) for token in doc5])
displacy.render(doc5)
# Out:
# [('Add', 'VB', 'VERB'), ('support', 'NN', 'NOUN'), ('for', 'IN', 'ADP'), ('the', 'DT', 'DET'), ('OSTC', 'NNP', 'PROPN'), ('2', 'CD', 'NUM'), ('TR', 'NN', 'NOUN')]
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="9be9ecfa9dc4475da7d9ae585a3e886e-0" class="displacy" width="1275" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Add</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">support</tspan>
# ...

# %%
doc6 = nlp("Suppress the warning if no O2 sensors are present")
for token in doc6:
    print([token.text, token.tag_, token.pos_])
# Out:
# ['Suppress', 'VB', 'VERB']
# ['the', 'DT', 'DET']
# ['warning', 'NN', 'NOUN']
# ['if', 'IN', 'SCONJ']
# ['no', 'DT', 'DET']
# ['O2', 'NNP', 'PROPN']
# ['sensors', 'NNS', 'NOUN']
# ['are', 'VBP', 'AUX']
# ['present', 'JJ', 'ADJ']

# %%
doc7 = nlp("Integrate the connect step into the open function")
print([(token.text, token.tag_, token.pos_) for token in doc7])
displacy.render(doc7)
# Out:
# [('Integrate', 'VB', 'VERB'), ('the', 'DT', 'DET'), ('connect', 'JJ', 'ADJ'), ('step', 'NN', 'NOUN'), ('into', 'IN', 'ADP'), ('the', 'DT', 'DET'), ('open', 'JJ', 'ADJ'), ('function', 'NN', 'NOUN')]
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="0563334761234e81b503d92cf2678e9c-0" class="displacy" width="1450" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Integrate</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">the</tspan>
# ...

# %%
doc8 = nlp("Implement some filter functions")
print([(token.text, token.tag_, token.pos_) for token in doc8])
displacy.render(doc8)
# Out:
# [('Implement', 'VB', 'VERB'), ('some', 'DT', 'DET'), ('filter', 'NN', 'NOUN'), ('functions', 'NNS', 'NOUN')]
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="9de9066fe25849d1ac201067ee49a086-0" class="displacy" width="750" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Implement</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">some</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">DET</tspan>
# </text>
#
# ...

# %%
doc9 = nlp("Add suport for applying a filter function")
print([(token.text, token.tag_, token.pos_) for token in doc9])
displacy.render(doc1)
# Out:
# [('Add', 'VB', 'VERB'), ('suport', 'NN', 'NOUN'), ('for', 'IN', 'ADP'), ('applying', 'VBG', 'VERB'), ('a', 'DT', 'DET'), ('filter', 'NN', 'NOUN'), ('function', 'NN', 'NOUN')]
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="7ec2b77a555d4ebfb03819c2270efb18-0" class="displacy" width="1800" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Remove</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">the</tspan>
# ...

# %%
doc10 = nlp("Disable some Windows specific compiler warnings")
print([(token.text, token.tag_, token.pos_) for token in doc10])
displacy.render(doc10)
# Out:
# [('Disable', 'VB', 'VERB'), ('some', 'DT', 'DET'), ('Windows', 'NNP', 'PROPN'), ('specific', 'JJ', 'ADJ'), ('compiler', 'NN', 'NOUN'), ('warnings', 'NNS', 'NOUN')]
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="4262eef8bbf84fc086144b355d71b1e7-0" class="displacy" width="1100" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Disable</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">some</tspan>
# ...

# %%
spacy.explain('pobj')
# Out:
# 'object of preposition'

# %%
doc13 = nlp("Correctly fix build without HID support")
print([(token.text, token.dep_, token.pos_) for token in doc13])
displacy.render(doc13)
# Out:
# [('Correctly', 'advmod', 'ADV'), ('fix', 'ROOT', 'VERB'), ('build', 'dobj', 'NOUN'), ('without', 'prep', 'ADP'), ('HID', 'compound', 'PROPN'), ('support', 'pobj', 'NOUN')]
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="5f3d61a1a5864b11b0dd251f1e6a2344-0" class="displacy" width="1100" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Correctly</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">fix</tspan>
# ...
