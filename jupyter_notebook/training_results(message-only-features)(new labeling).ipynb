# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
from matplotlib import pyplot as plt
from sklearn.metrics import f1_score

# %%
data = pd.read_csv('../data/data_msg_only(new tags).csv')
x = data.drop(columns=['label'])
y = data['label']

# %%
def display_importances(imp, names):
    imp, names = zip(*sorted(zip(imp, names)))
    plt.barh(range(len(names)), imp)
    plt.yticks(range(len(names)), names)
    plt.show()

# %%
features_names = ['characters_count', 'and_or',  'blank_line', 'capital_start', 'end_dot', 'imperative_start', 'wrap_to_72',
                  'verb_obj_conn']

# %%
clf = DecisionTreeClassifier()
clf.fit(x, y)
display_importances(clf.feature_importances_, features_names)

# %% [markdown]
# ---

# %%
clf = RandomForestClassifier()
clf.fit(x, y)
display_importances(clf.feature_importances_, features_names)

# %% [markdown]
# ---

# %%
clf = ExtraTreesClassifier()
clf.fit(x, y)
display_importances(clf.feature_importances_, features_names)

# %% [markdown]
# ---

# %%
clf = GradientBoostingClassifier()
clf.fit(x, y)
display_importances(clf.feature_importances_, features_names)

# %% [markdown]
# ---

# %% [markdown]
# DecisionTreeClassifier(whole commit): [highest 0.78] [accuracy 0.71] [time 0.56]
#
# DecisionTreeClassifier(message only): [highest 0.72] [accuracy 0.61] [time 0.4]
#
# ---
#
# RandomForestClassifier(whole commit): [highest 0.86] [accuracy 0.77] [time 15.11]
#
# RandomForestClassifier(message only): [highest 0.68] [accuracy 0.62] [time 13.4]
#
# ---
#
# ExtraTreesClassifier(whole commit): [highest 0.8] [accuracy 0.74] [time 13.71]
#
# ExtraTreesClassifier(message only): [highest 0.68] [accuracy 0.61] [time 11.48]
#
# ---
#
# GradientBoostingClassifier(whole commit): [highest 0.84] [accuracy 0.77] [time 38.41]
#
# GradientBoostingClassifier(message only): [highest 0.78] [accuracy 0.67] [time 23.82]

# %%
data_good = data[data.label == 'good']
data_neutral = data[data.label == 'neutral']
data_bad = data[data.label == 'bad']

# %%
plt.ylim(0,200)
plt.title("good")
plt.scatter(x=data_good.index, y=data_good['characters_count'], s=5); 
plt.hlines(y=data_good['characters_count'].mean(), xmin=0, xmax=1000) # Mean line
plt.show()
print('Standard Deviation:', data_good['characters_count'].std())

plt.title("neutral")
plt.ylim(0,200)
plt.scatter(x=data_neutral.index, y=data_neutral['characters_count'], s=5);
plt.hlines(y=data_neutral['characters_count'].mean(), xmin=0, xmax=1000);
plt.show()
print('Standard Deviation:', data_neutral['characters_count'].std())

plt.title("bad")
plt.ylim(0,200)
plt.scatter(x=data_bad.index, y=data_bad['characters_count'], s=5);
plt.hlines(y=data_bad['characters_count'].mean(), xmin=0, xmax=1000);
plt.show()
print('Standard Deviation:', data_bad['characters_count'].std())
# Out:
# Standard Deviation: 11.707729205651773
# Standard Deviation: 18.30763103462222
# Standard Deviation: 37.37451556916957

# %%
plt.ylim(0,75)
plt.title("good")
plt.scatter(x=data_good.index, y=data_good['characters_count'], s=5); 
plt.hlines(y=data_good['characters_count'].mean(), xmin=0, xmax=1000) # Mean line
plt.show()
print('Standard Deviation:', data_good['characters_count'].std())

plt.title("neutral")
plt.ylim(0,100)
plt.scatter(x=data_neutral.index, y=data_neutral['characters_count'], s=5);
plt.hlines(y=data_neutral['characters_count'].mean(), xmin=0, xmax=1000);
plt.show()
print('Standard Deviation:', data_neutral['characters_count'].std())

plt.title("bad")
plt.ylim(0,200)
plt.scatter(x=data_bad.index, y=data_bad['characters_count'], s=5);
plt.hlines(y=data_bad['characters_count'].mean(), xmin=0, xmax=1000);
plt.show()
print('Standard Deviation:', data_bad['characters_count'].std())
# Out:
# Standard Deviation: 11.707729205651773
# Standard Deviation: 18.30763103462222
# Standard Deviation: 37.37451556916957

# %%
plt.ylim(-0.2,1.2)
plt.title("good")
plt.scatter(x=data_good.index, y=data_good['verb_obj_conn'], s=5); 
plt.hlines(y=data_good['verb_obj_conn'].mean(), xmin=0, xmax=1000) # Mean line
plt.show()
print('Standard Deviation:', data_good['verb_obj_conn'].std())

plt.title("neutral")
plt.ylim(-0.2,1.2)
plt.scatter(x=data_neutral.index, y=data_neutral['verb_obj_conn'], s=5);
plt.hlines(y=data_neutral['verb_obj_conn'].mean(), xmin=0, xmax=1000);
plt.show()
print('Standard Deviation:', data_neutral['verb_obj_conn'].std())

plt.title("bad")
plt.ylim(-0.2,1.2)
plt.scatter(x=data_bad.index, y=data_bad['verb_obj_conn'], s=5);
plt.hlines(y=data_bad['verb_obj_conn'].mean(), xmin=0, xmax=1000);
plt.show()
print('Standard Deviation:', data_bad['verb_obj_conn'].std())
# Out:
# Standard Deviation: 0.09805460980810282
# Standard Deviation: 0.3692237216988363
# Standard Deviation: 0.499792586438081

# %%
from sklearn.tree import export_text
tree_rules = export_text(clf, feature_names=features_names)
print(tree_rules)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-3f19c243b509> in <module>
#       1 from sklearn.tree import export_text
# ----> 2 tree_rules = export_text(clf, feature_names=features_names)
#       3 print(tree_rules)
#
# c:\users\jano0\desktop\commitquality\venv\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# c:\users\jano0\desktop\commitquality\venv\lib\site-packages\sklearn\tree\_export.py in export_text(decision_tree, feature_names, max_depth, spacing, decimals, show_weights)
#     875     """
#     876     check_is_fitted(decision_tree)
# --> 877     tree_ = decision_tree.tree_
#     878     if is_classifier(decision_tree):
#     879         class_names = decision_tree.classes_
#
# AttributeError: 'ExtraTreesClassifier' object has no attribute 'tree_'
